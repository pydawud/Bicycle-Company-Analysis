# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
file = pd.ExcelFile('KPMG_bicycle.xlsx')
file.sheet_names
# Out:
# ['Title Sheet',
#  'Transactions',
#  'NewCustomerList',
#  'CustomerDemographic',
#  'CustomerAddress']

# %%
df_tran = pd.read_excel(file, 'Transactions', header=1)
#df_newcus = pd.read_excel(file, 'NewCustomerList')
#df_cusdem = pd.read_excel(file, 'CustomerDemographic')
#df_cusadd = pd.read_excel(file, 'CustomerAddress')

# %% [markdown]
# ## Transactions Sheet

# %%
df_tran.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
df_tran.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %% [markdown]
# 20,000 records, 13 columns with 7 columns having missing values

# %% [markdown]
# ## 1. Data Quality dimension Issue: Completeness

# %%
df_tran.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
#let's the null values
df_tran[df_tran['online_order'].isnull()]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 97                 98          49          333       2017-06-23           NaN
# 166               167          90         3177       2017-04-26           NaN
# 169               170           6          404       2017-10-16           NaN
# 250               251          63         1967       2017-04-11           NaN
# 300               301          78         2530       2017-03-24           NaN
# ...               ...         ...          ...              ...           ...
# 19514           19515          51          690       2017-01-22           NaN
# 19573           19574          18         1735       2017-01-15           NaN
# 19580           19581          49         1933       2017-10-12           NaN
# 19635           19636          98         1389       2017-07-26           NaN
# 19843           19844           3            8       2017-01-28           NaN
#
# ...

# %%
df_tran[df_tran['brand'].isnull()]
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 136               137           0          431       2017-09-23           0.0
# 159               160           0         3300       2017-08-27           0.0
# 366               367           0         1614       2017-03-10           0.0
# 406               407           0         2559       2017-06-14           1.0
# 676               677           0         2609       2017-07-02           0.0
# ...               ...         ...          ...              ...           ...
# 19340           19341           0          443       2017-12-26           1.0
# 19383           19384           0         2407       2017-06-11           0.0
# 19793           19794           0         2860       2017-01-13           0.0
# 19859           19860           0         2468       2017-06-24           1.0
# 19871           19872           0           61       2017-03-17           1.0
#
# ...

# %% [markdown]
# ## 2. Accuracy
# In accuracy, we look at the data types issues, and correct values.

# %%
df_tran.describe()
# Out:
#        transaction_id   product_id   customer_id  online_order    list_price  \
# count    20000.000000  20000.00000  20000.000000  19640.000000  20000.000000
# mean     10000.500000     45.36465   1738.246050      0.500458   1107.829449
# std       5773.647028     30.75359   1011.951046      0.500013    582.825242
# min          1.000000      0.00000      1.000000      0.000000     12.010000
# 25%       5000.750000     18.00000    857.750000      0.000000    575.270000
# 50%      10000.500000     44.00000   1736.000000      1.000000   1163.890000
# 75%      15000.250000     72.00000   2613.000000      1.000000   1635.300000
# max      20000.000000    100.00000   5034.000000      1.000000   2091.470000
#
#        standard_cost  product_first_sold_date
# count   19803.000000             19803.000000
# mean      556.046951             38199.776549
# std       405.955660              2875.201110
# min         7.210000             33259.000000
# ...

# %%
#lets observe unique product ids
df_tran['product_id'].unique()
# Out:
# array([  2,   3,  37,  88,  78,  25,  22,  15,  67,  12,   5,  61,  35,
#         16,  79,  33,  54,  27,  82,  89,  64,  19,  72,  91,   1,  99,
#          0,  92,  14,  44,  76,  46,  55,  66,  81,  86,  32,  77,  96,
#          6,  47,  94,  93,  60,  28,   4,  38,  56,  58,  50,  80,  87,
#         84,  21,  31,  62,  17,  73,  45,  49,  95,  18,  70,  26,  39,
#         36,  98,  75,  42,  20,  24,  53,  65,  29,  11,  10,   7,  41,
#          9,  69,  90,  97, 100,  74,  71,  34,  57,  23,  51,  59,  63,
#         40,   8,  13,  30,  48,  68,  83,  43,  52,  85], dtype=int64)

# %%
df_tran.query('product_id == 0')
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 34                 35           0         2171       2017-08-20           0.0
# 39                 40           0         2448       2017-11-28           1.0
# 54                 55           0         3140       2017-09-18           0.0
# 60                 61           0         1839       2017-02-24           0.0
# 63                 64           0         2000       2017-07-08           0.0
# ...               ...         ...          ...              ...           ...
# 19921           19922           0         1869       2017-01-06           1.0
# 19941           19942           0          966       2017-07-30           1.0
# 19967           19968           0         2751       2017-04-06           0.0
# 19987           19988           0           13       2017-04-05           1.0
# 19988           19989           0          714       2017-04-27           1.0
#
# ...

# %% [markdown]
# product_id 0 is suspicious. the id should be a valid number

# %%
#lets observe online_order
df_tran['online_order'].unique()
# Out:
# array([ 0.,  1., nan])

# %% [markdown]
# The value should be int (0/1) or Boolean (True/False)

# %%
#lets observe `order_status` column
df_tran['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
#lets observe `brand` column
df_tran['brand'].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
#lets observe `product_line` column
df_tran['product_line'].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
#lets observe `product_class` column
df_tran['product_class'].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
#lets observe `product_size` column
df_tran['product_size'].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %% [markdown]
# ## NewCustomerList Sheet

# %%
df_newcus = pd.read_excel(file, 'NewCustomerList', header=1)
df_newcus.head()
# Out:
# C:\Users\d\AppData\Local\Temp\ipykernel_12452\3612415788.py:1: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   df_newcus = pd.read_excel(file, 'NewCustomerList', header=1)
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# ...

# %%
df_newcus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %% [markdown]
# 1000 new customers, 23 features with 3 columns have missing values

# %%
df_newcus.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
df_newcus.describe()
# Out:
#        past_3_years_bike_related_purchases       tenure     postcode  \
# count                          1000.000000  1000.000000  1000.000000
# mean                             49.836000    11.388000  3019.227000
# std                              27.796686     5.037145   848.895767
# min                               0.000000     0.000000  2000.000000
# 25%                              26.750000     7.000000  2209.000000
# 50%                              51.000000    11.000000  2800.000000
# 75%                              72.000000    15.000000  3845.500000
# max                              99.000000    22.000000  4879.000000
#
#        property_valuation  Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# count         1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean             7.397000     0.747340     0.839005     0.942673     0.870514
# std              2.758804     0.205082     0.248858     0.294832     0.280891
# ...

# %%
#lets inpect the columns
df_newcus['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %% [markdown]
# Gender should contain meaninful values, replace `U` with `other`

# %%
df_newcus['DOB'].unique()[:5]
# Out:
# array(['1957-07-12T00:00:00.000000000', '1970-03-22T00:00:00.000000000',
#        '1974-08-28T00:00:00.000000000', '1979-01-28T00:00:00.000000000',
#        '1965-09-21T00:00:00.000000000'], dtype='datetime64[ns]')

# %% [markdown]
#  the DOB need to be converted to the right datatype and format

# %%
df_newcus.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value'],
#       dtype='object')

# %%
df_newcus['job_title'].value_counts()
# Out:
# Associate Professor         15
# Environmental Tech          14
# Software Consultant         14
# Chief Design Engineer       13
# Assistant Manager           12
#                             ..
# Accountant II                1
# Programmer IV                1
# Administrative Officer       1
# Accounting Assistant III     1
# Web Developer I              1
# Name: job_title, Length: 184, dtype: int64

# %%
df_newcus['job_industry_category'].value_counts()
# Out:
# Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %%
df_newcus['wealth_segment'].value_counts()
# Out:
# Mass Customer        508
# High Net Worth       251
# Affluent Customer    241
# Name: wealth_segment, dtype: int64

# %%
df_newcus['deceased_indicator'].value_counts()
# Out:
# N    1000
# Name: deceased_indicator, dtype: int64

# %% [markdown]
# Unique, should be discarded

# %%
df_newcus['owns_car'].value_counts()
# Out:
# No     507
# Yes    493
# Name: owns_car, dtype: int64

# %%
df_newcus['state'].value_counts()
# Out:
# NSW    506
# VIC    266
# QLD    228
# Name: state, dtype: int64

# %%
df_newcus['country'].value_counts()
# Out:
# Australia    1000
# Name: country, dtype: int64

# %% [markdown]
# unique, should be discarded

# %% [markdown]
# ## Issues
# Transactions Sheet
# 1. product_first_sold_date the title is misleading
# 2. missing values in online_order, brand, product_line, product_sales, product_size, list_price, standard_cost and product_first_sold_date
# 3. product_id with value 0
# 4. online_order value should not be a float, it should be int with 0/1, or Boolean with True/False
# 5. tidy issues: customer details, product details should be in separate table.
#
# NewCustomerList Sheet
# 1. Four columns doesnt have name description
# 2. past_3_years_bike_related_purchases column name is too long
# 3. deceased_indicator and owns_car there values should be consistent
# 4. missing values in last_name, job_title, DOB, and job_industry_category.
# 5. Gender has invalid value 'U'
# 6. DOB date format need to be converted to the right datatype
# 7. deceased indicator is unique, therefore not important, it should be discarded
# 8. country is unique, should be discarded.
# 9.
